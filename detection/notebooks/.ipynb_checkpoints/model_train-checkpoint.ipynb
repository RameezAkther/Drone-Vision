# %%
# !git clone https://github.com/RameezAkther/DroneVisionProject.git
# Out:
# Cloning into 'DroneVisionProject'...
# remote: Enumerating objects: 314, done.
# remote: Counting objects: 100% (314/314), done.
# remote: Compressing objects: 100% (308/308), done.
# remote: Total 314 (delta 123), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (314/314), 114.74 KiB | 5.74 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
# !pip install -r /kaggle/working/DroneVisionProject/rtdetr_pytorch/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 100.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 89.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 102.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 110.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 83.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 16.7 MB/s eta 0:00:00
# ...

# %%
cd /kaggle/working/DroneVisionProject/rtdetr_pytorch
# Out:
# /kaggle/working/DroneVisionProject/rtdetr_pytorch

# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
# !python tools/train.py -c configs/rtdetr/rtdetr_r50vd_seadronessee.yml -r /kaggle/input/rt-detr-trained-on-seadronessee-dataset/pytorch/default/11/checkpoint49.pth
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 2.0.1
# Not init distributed mode.
# Start training
# Downloading: "https://github.com/lyuwenyu/storage/releases/download/v0.1/ResNet50_vd_ssld_v2_pretrained_from_paddle.pth" to /root/.cache/torch/hub/checkpoints/ResNet50_vd_ssld_v2_pretrained_from_paddle.pth
# 100%|███████████████████████████████████████| 90.0M/90.0M [00:00<00:00, 114MB/s]
# Load PResNet50 state_dict
# Initial lr:  [1e-05, 0.0001, 0.0001, 0.0001]
# Resume checkpoint from /kaggle/input/rt-detr-trained-on-seadronessee-dataset/pytorch/default/11/checkpoint49.pth
# Loading last_epoch
# Loading model.state_dict
# Loading ema.state_dict
# Loading optimizer.state_dict
# Loading lr_scheduler.state_dict
# loading annotations into memory...
# Done (t=1.14s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# number of params: 42704625
# ...

# %%
# !python tools/train.py \
  -c configs/rtdetr/rtdetr_r50vd_seadronessee.yml \
  -r output/rtdetr_r50vd_seadronessee/checkpoint.pth \
  --test-only
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 2.0.1
# Not init distributed mode.
# Load PResNet50 state_dict
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!
# resume from output/rtdetr_r50vd_seadronessee/checkpoint.pth
# Loading last_epoch
# Loading model.state_dict
# Loading ema.state_dict
# Test:  [  0/459]  eta: 0:31:13    time: 4.0828  data: 2.1423  max mem: 1469
# Test:  [ 10/459]  eta: 0:05:57    time: 0.7952  data: 0.2560  max mem: 1477
# Test:  [ 20/459]  eta: 0:04:56    time: 0.5061  data: 0.0607  max mem: 1477
# Test:  [ 30/459]  eta: 0:04:30    time: 0.5407  data: 0.0483  max mem: 1477
# Test:  [ 40/459]  eta: 0:04:13    time: 0.5299  data: 0.0446  max mem: 1477
# Test:  [ 50/459]  eta: 0:03:56    time: 0.4987  data: 0.0467  max mem: 1477
# Test:  [ 60/459]  eta: 0:03:47    time: 0.4958  data: 0.0525  max mem: 1477
# Test:  [ 70/459]  eta: 0:03:38    time: 0.5136  data: 0.0522  max mem: 1477
# ...

# %%
# !python tools/infer.py -c configs/rtdetr/rtdetr_r50vd_seadronessee.yml \
#   -r output/rtdetr_r50vd_seadronessee/checkpoint.pth \
#   -f /kaggle/input/inference-sample/0.jpg
