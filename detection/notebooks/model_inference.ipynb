# %%
# !git clone https://github.com/RameezAkther/DroneVisionProject.git
# Out:
# Cloning into 'DroneVisionProject'...
# remote: Enumerating objects: 324, done.
# remote: Counting objects: 100% (324/324), done.
# remote: Compressing objects: 100% (318/318), done.
# remote: Total 324 (delta 127), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (324/324), 1.08 MiB | 8.56 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %%
# !pip install -r /kaggle/working/DroneVisionProject/rtdetr_pytorch/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 105.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 101.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 113.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 84.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 17.1 MB/s eta 0:00:00
# ...

# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
cd /kaggle/working/DroneVisionProject/rtdetr_pytorch
# Out:
# /kaggle/working/DroneVisionProject/rtdetr_pytorch

# %%
# !python tools/infer_v2.py \
  --config configs/rtdetr/rtdetr_r50vd_seadronessee.yml \
  --resume /kaggle/input/rt-detr-trained-on-seadronessee-dataset/pytorch/default/1/checkpoint.pth \
  --folder /kaggle/input/inference-sample/Images \
  --out-dir /kaggle/working/DroneVisionProject/rtdetr_pytorch/result \
  --device cuda
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 2.0.1
# Downloading: "https://github.com/lyuwenyu/storage/releases/download/v0.1/ResNet50_vd_ssld_v2_pretrained_from_paddle.pth" to /root/.cache/torch/hub/checkpoints/ResNet50_vd_ssld_v2_pretrained_from_paddle.pth
# 100%|███████████████████████████████████████| 90.0M/90.0M [00:00<00:00, 146MB/s]
# Load PResNet50 state_dict
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_16372.jpg
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_18218.jpg
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_27001.jpg
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_47281.jpg
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_5042.jpg
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_20442.jpg
# ...

# %%
# !python tools/infer_v2.py \
  --config configs/rtdetr/rtdetr_r50vd_seadronessee.yml \
  --resume /kaggle/input/rt-detr-trained-on-seadronessee-dataset/pytorch/default/1/checkpoint.pth \
  --folder /kaggle/input/inference-sample/Videos \
  --out-dir /kaggle/working/DroneVisionProject/rtdetr_pytorch/result \
  --device cuda
# Out:
# Disabling PyTorch because PyTorch >= 2.1 is required but found 2.0.1
# Load PResNet50 state_dict
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_floatig_2_40m.mp4
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_floating_1_30m.mp4
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_floating_3_40m.mp4
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_distress_signal_1_20m.mp4
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_swimming_2_40m.mp4
# ✅ Saved /kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_swimming_1_30m.mp4

# %%
# !zip -r inference_result.zip /kaggle/working/DroneVisionProject/rtdetr_pytorch/result
# Out:
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/ (stored 0%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_11493.jpg (deflated 3%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_5042.jpg (deflated 0%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_16372.jpg (deflated 2%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_18218.jpg (deflated 4%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_35222.jpg (deflated 4%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_swimming_2_40m.mp4 (deflated 1%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_floating_3_40m.mp4 (deflated 1%)
#   adding: kaggle/working/DroneVisionProject/rtdetr_pytorch/result/inferenced_44511.jpg (deflated 7%)
# ...
